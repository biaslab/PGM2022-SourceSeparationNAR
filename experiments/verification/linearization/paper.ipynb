# %%
include("create_figure.jl")
# Out:
# GroupPlot(PGFPlotsX.Options(OrderedCollections.OrderedDict{Any, Any}("group_style" => PGFPlotsX.Options(OrderedCollections.OrderedDict{Any, Any}("group_size" => "1 by 3", "vertical_sep" => "0.5cm"), true), "label_style" => PGFPlotsX.Options(OrderedCollections.OrderedDict{Any, Any}("font" => "\\footnotesize"), true), "legend_style" => PGFPlotsX.Options(OrderedCollections.OrderedDict{Any, Any}("font" => "\\footnotesize", "row_sep" => "-3pt"), true), "ticklabel_style" => PGFPlotsX.Options(OrderedCollections.OrderedDict{Any, Any}("font" => "\\scriptsize"), true)), true), Any[PGFPlotsX.Options(OrderedCollections.OrderedDict{Any, Any}("grid" => "major", "style" => PGFPlotsX.Options(OrderedCollections.OrderedDict{Any, Any}("thick" => nothing), true), "width" => "6in", "height" => "3cm", "xmin" => 0, "xmax" => 250, "ymin" => -6, "ymax" => 6), true), Plot(false, false, PGFPlotsX.Options(OrderedCollections.OrderedDict{Any, Any}("name path=signal1" => nothing, "draw" => "none", "forget_plot" =>
# ...
